# %%
# Importing the Violations Dataset with only required columns
import pandas as pd

df = pd.read_csv(r"Parking_Violations_Issued_2019-2021.csv",
                usecols = ['Summons Number','Plate ID','Registration State','Plate Type','Issue Date','Violation Code','Vehicle Body Type','Vehicle Make','Issuing Agency','Violation Precinct','Issuer Precinct','Violation Time','Violation County','Vehicle Color','Vehicle Year'])
df.shape
# Out:
# (23497573, 15)

# %%
df.head()
# Out:
#    Summons Number  Plate ID Registration State Plate Type  \
# 0      1465574475   JMJ4156                 99        PAS
# 1      1452758967  T753575C                 NY        OMT
# 2      1460097804   JMU9251                 NY        PAS
# 3      1452790565   AV32960                 CT        999
# 4      1455416400    2XU096                 OK        PAS
#
#                Issue Date  Violation Code Vehicle Body Type Vehicle Make  \
# 0  01/01/2019 12:00:00 AM              98               SDN        HONDA
# 1  01/01/2019 12:00:00 AM              71               SDN        TOYOT
# 2  01/01/2019 12:00:00 AM              70               SDN        HONDA
# 3  01/01/2019 12:00:00 AM              40              SUBN        MITSU
# 4  01/01/2019 12:00:00 AM              17              DELV        INTER
#
#   Issuing Agency  Violation Precinct  Issuer Precinct Violation Time  \
# 0              P                  75               75          1048A
# 1              P                 102              402          0150P
# 2              P                 113              113          0700A
# 3              P                 115              401          1222P
# 4              P                   1              105          0815A
#
#   Violation County Vehicle Color  Vehicle Year
# 0                K          GOLD             0
# 1                Q           BLK          2016
# 2                Q            GY          2010
# 3                Q           WHT             0
# 4              NaN            WH             0

# %%
# Formatting the issue date timestamp and parsing the month-year
df['Issue Date'] = pd.to_datetime(df['Issue Date'])
df['Issue_month_year'] = df['Issue Date'].dt.strftime('%B-%Y')
df['Issue_year'] = df['Issue Date'].dt.strftime('%Y')

# %%
#Summarizing by month-year. Aggregation should be done at yearly level as monthly distributions are skewed.
df.Issue_month_year.value_counts(ascending = True)
# Out:
# March-2019             47
# February-2019          68
# April-2019            101
# March-2021            165
# February-2021         171
# April-2020            186
# April-2021            190
# February-2020         195
# May-2021              335
# March-2020            374
# January-2019          456
# January-2020          565
# January-2021          658
# May-2019             8237
# May-2020            12065
# June-2019          226351
# June-2020          240540
# June-2021          251427
# December-2019      992954
# July-2020         1050234
# December-2020     1161109
# December-2021     1164148
# July-2019         1164693
# September-2021    1190870
# November-2019     1191674
# September-2019    1229541
# November-2020     1264936
# October-2019      1276499
# November-2021     1284437
# August-2019       1331903
# October-2021      1346703
# August-2020       1403657
# July-2021         1404374
# August-2021       1419732
# October-2020      1421643
# September-2020    1456335
# Name: Issue_month_year, dtype: int64

# %%
# Checking for Valid State Codes
df['Registration State'].value_counts(ascending = True)
# Out:
# NT           3
# YT           4
# MX          13
# SK          21
# PE          26
#         ...
# CT      344169
# FL      425771
# PA      716243
# NJ     2219741
# NY    17753475
# Name: Registration State, Length: 68, dtype: int64

# %%
# Removing Invalid State Codes
state_codes = pd.read_excel(r"State-Codes.xlsx")
df = pd.merge(df, state_codes, left_on = "Registration State", right_on ='State Code' , how = "inner")
df.shape
# Out:
# (23415023, 20)

# %%
df.head()
# Out:
#    Summons Number  Plate ID Registration State Plate Type Issue Date  \
# 0      1452758967  T753575C                 NY        OMT 2019-01-01
# 1      1460097804   JMU9251                 NY        PAS 2019-01-01
# 2      1464592822   31328WG                 NY        COM 2019-01-02
# 3      1464592810   63422JM                 NY        COM 2019-01-02
# 4      1464592809   48799JU                 NY        COM 2019-01-02
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0              71               SDN        TOYOT              P
# 1              70               SDN        HONDA              P
# 2              14              DELV        FRUEH              P
# 3              14              DELV        INTER              P
# 4              14               VAN        DODGE              P
#
#    Violation Precinct  Issuer Precinct Violation Time Violation County  \
# 0                 102              402          0150P                Q
# 1                 113              113          0700A                Q
# 2                  18              401          0432P               NY
# 3                  18              401          0548P               NY
# 4                  18              401          0555P               NY
#
#   Vehicle Color  Vehicle Year Issue_month_year Issue_year     State  \
# 0           BLK          2016     January-2019       2019  New York
# 1            GY          2010     January-2019       2019  New York
# 2         WHITE          2004     January-2019       2019  New York
# 3         BROWN          1998     January-2019       2019  New York
# 4         WHITE          2005     January-2019       2019  New York
#
#   Abbreviation State Code
# 0         N.Y.         NY
# 1         N.Y.         NY
# 2         N.Y.         NY
# 3         N.Y.         NY
# 4         N.Y.         NY

# %%
#Checking for null values
print(df.isnull().sum())
# Out:
# Summons Number              0
# Plate ID                  215
# Registration State          0
# Plate Type                  0
# Issue Date                  0
# Violation Code              0
# Vehicle Body Type       65720
# Vehicle Make            60392
# Issuing Agency              0
# Violation Precinct          0
# Issuer Precinct             0
# Violation Time            393
# Violation County        58349
# Vehicle Color         1151666
# Vehicle Year                0
# Issue_month_year            0
# Issue_year                  0
# State                       0
# Abbreviation            94232
# State Code                  0
# dtype: int64

# %%
# Dropping the rows having NaN/NaT values in key attributes

df = df.dropna(subset=['Plate ID'])
df = df.dropna(subset=['Violation Time'])
 
# Resetting the indices using df.reset_index()
df = df.reset_index(drop=True)
df.shape
# Out:
# (23414415, 20)

# %%
#Imputing the missing values
df['Vehicle Body Type'].fillna(df['Vehicle Body Type'].mode()[0], inplace = True)
df['Vehicle Make'].fillna(df['Vehicle Make'].mode()[0], inplace = True)
df['Violation County'].fillna(df['Violation County'].mode()[0], inplace = True)
df['Vehicle Color'].fillna(df['Vehicle Color'].mode()[0], inplace = True)
df['Vehicle Year'].fillna(df['Vehicle Year'].mode()[0], inplace = True)

# %%
#Keeping Required columns
col_list = ['Summons Number','Plate ID','Registration State','Plate Type','Issue Date','Violation Code','Vehicle Body Type','Vehicle Make','Issuing Agency','Violation Precinct','Issuer Precinct','Violation Time','Violation County','Vehicle Color','Vehicle Year','State','Issue_month_year','Issue_year']
df = df[col_list]

# %%
print(df.isnull().sum())
# Out:
# Summons Number        0
# Plate ID              0
# Registration State    0
# Plate Type            0
# Issue Date            0
# Violation Code        0
# Vehicle Body Type     0
# Vehicle Make          0
# Issuing Agency        0
# Violation Precinct    0
# Issuer Precinct       0
# Violation Time        0
# Violation County      0
# Vehicle Color         0
# Vehicle Year          0
# State                 0
# Issue_month_year      0
# Issue_year            0
# dtype: int64

# %%
#Parsing the Violiaton Time
import datetime
import re
#tme='0612A' 
#pd.to_datetime(tme).strftime('%H:%M%p')
#df['Violation Time'] = pd.to_datetime(df['Violation Time'],format = '%H%m%p',errors='raise' )
#format = '%H%M%p'

df['new_violation_time'] = df['Violation Time'].str.replace(r'(\w{2})(\w{2})(\w{1})', r'\1:\2', regex=True)
df['new_violation_time_AP'] = df['Violation Time'].str.replace(r'(\w{2})(\w{2})(\w{1})', r'\3', regex=True)
df['new_violation_time_AP'] = df['new_violation_time'] + df['new_violation_time_AP'].apply(lambda n: 'AM' if n == 'A' else 'PM')
df.head()
# Out:
#    Summons Number  Plate ID Registration State Plate Type Issue Date  \
# 0      1452758967  T753575C                 NY        OMT 2019-01-01
# 1      1460097804   JMU9251                 NY        PAS 2019-01-01
# 2      1464592822   31328WG                 NY        COM 2019-01-02
# 3      1464592810   63422JM                 NY        COM 2019-01-02
# 4      1464592809   48799JU                 NY        COM 2019-01-02
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0              71               SDN        TOYOT              P
# 1              70               SDN        HONDA              P
# 2              14              DELV        FRUEH              P
# 3              14              DELV        INTER              P
# 4              14               VAN        DODGE              P
#
#    Violation Precinct  Issuer Precinct Violation Time Violation County  \
# 0                 102              402          0150P                Q
# 1                 113              113          0700A                Q
# 2                  18              401          0432P               NY
# 3                  18              401          0548P               NY
# 4                  18              401          0555P               NY
#
#   Vehicle Color  Vehicle Year     State Issue_month_year Issue_year  \
# 0           BLK          2016  New York     January-2019       2019
# 1            GY          2010  New York     January-2019       2019
# 2         WHITE          2004  New York     January-2019       2019
# 3         BROWN          1998  New York     January-2019       2019
# 4         WHITE          2005  New York     January-2019       2019
#
#   new_violation_time new_violation_time_AP
# 0              01:50               01:50PM
# 1              07:00               07:00AM
# 2              04:32               04:32PM
# 3              05:48               05:48PM
# 4              05:55               05:55PM

# %%
# Importing the metadata for registractin codes description, violation code description and vehicel body descrption
registration_codes = pd.read_excel(r"Registration-Codes-Metadata.xlsx")
violation_codes = pd.read_excel(r"ParkingViolationCodes_January2020.xlsx")
vehiclebody_codes = pd.read_excel(r"Vehicle-Body-Type-Metadata.xlsx")
registration_codes.head()
# Out:
#                    Description Code
# 0           Air National Guard  ARG
# 1          Army National Guard  AYG
# 2  County Board of Supervisors  CBS
# 3                 County Clerk  CCK
# 4           County Legislators  CLG

# %%
# Merging the metadata for registractin codes description, violation code description and vehicel body descrption
df_1 = pd.merge(df, registration_codes, left_on = "Plate Type", right_on ='Code' , how = "left")
df_2 = pd.merge(df_1, violation_codes, left_on = "Violation Code", right_on ='VIOLATION CODE' , how = "left")
df_3 = pd.merge(df_2, vehiclebody_codes, left_on = "Vehicle Body Type", right_on ='Code' , how = "left")
df_3.head()
# Out:
#    Summons Number  Plate ID Registration State Plate Type Issue Date  \
# 0      1452758967  T753575C                 NY        OMT 2019-01-01
# 1      1460097804   JMU9251                 NY        PAS 2019-01-01
# 2      1464592822   31328WG                 NY        COM 2019-01-02
# 3      1464592810   63422JM                 NY        COM 2019-01-02
# 4      1464592809   48799JU                 NY        COM 2019-01-02
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0              71               SDN        TOYOT              P
# 1              70               SDN        HONDA              P
# 2              14              DELV        FRUEH              P
# 3              14              DELV        INTER              P
# 4              14               VAN        DODGE              P
#
#    Violation Precinct  ...  new_violation_time new_violation_time_AP  \
# 0                 102  ...               01:50               01:50PM
# 1                 113  ...               07:00               07:00AM
# 2                  18  ...               04:32               04:32PM
# 3                  18  ...               05:48               05:48PM
# 4                  18  ...               05:55               05:55PM
#
#                    Description Code_x  VIOLATION CODE  \
# 0  Taxi & Limousine Commission    OMT            71.0
# 1                    Passenger    PAS            70.0
# 2          Commercial Vehicles    COM            14.0
# 3          Commercial Vehicles    COM            14.0
# 4          Commercial Vehicles    COM            14.0
#
#            VIOLATION DESCRIPTION Fine Amount Fine_Amount_Others  \
# 0  INSP. STICKER-EXPIRED/MISSING        65.0               65.0
# 1   REG. STICKER-EXPIRED/MISSING        65.0               65.0
# 2    NO STANDING-DAY/TIME LIMITS       115.0              115.0
# 3    NO STANDING-DAY/TIME LIMITS       115.0              115.0
# 4    NO STANDING-DAY/TIME LIMITS       115.0              115.0
#
#   Vehicle Description Code_y
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2                 NaN    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN
#
# [5 rows x 28 columns]

# %%
col_list = ['Summons Number','Plate ID','Registration State','Plate Type','Issue Date','Violation Code','Vehicle Body Type','Vehicle Make','Issuing Agency','Violation Precinct','Issuer Precinct','Violation Time','Violation County','Vehicle Color','Vehicle Year','State','Issue_month_year','Issue_year','new_violation_time_AP','Description','VIOLATION DESCRIPTION','Fine Amount']
final_df = df_3[col_list]
final_df.shape
# Out:
# (23426275, 22)

# %%
final_df.head()
# Out:
#    Summons Number  Plate ID Registration State Plate Type Issue Date  \
# 0      1452758967  T753575C                 NY        OMT 2019-01-01
# 1      1460097804   JMU9251                 NY        PAS 2019-01-01
# 2      1464592822   31328WG                 NY        COM 2019-01-02
# 3      1464592810   63422JM                 NY        COM 2019-01-02
# 4      1464592809   48799JU                 NY        COM 2019-01-02
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0              71               SDN        TOYOT              P
# 1              70               SDN        HONDA              P
# 2              14              DELV        FRUEH              P
# 3              14              DELV        INTER              P
# 4              14               VAN        DODGE              P
#
#    Violation Precinct  ...  Violation County Vehicle Color Vehicle Year  \
# 0                 102  ...                 Q           BLK         2016
# 1                 113  ...                 Q            GY         2010
# 2                  18  ...                NY         WHITE         2004
# 3                  18  ...                NY         BROWN         1998
# 4                  18  ...                NY         WHITE         2005
#
#       State  Issue_month_year Issue_year new_violation_time_AP  \
# 0  New York      January-2019       2019               01:50PM
# 1  New York      January-2019       2019               07:00AM
# 2  New York      January-2019       2019               04:32PM
# 3  New York      January-2019       2019               05:48PM
# 4  New York      January-2019       2019               05:55PM
#
#                    Description          VIOLATION DESCRIPTION Fine Amount
# 0  Taxi & Limousine Commission  INSP. STICKER-EXPIRED/MISSING        65.0
# 1                    Passenger   REG. STICKER-EXPIRED/MISSING        65.0
# 2          Commercial Vehicles    NO STANDING-DAY/TIME LIMITS       115.0
# 3          Commercial Vehicles    NO STANDING-DAY/TIME LIMITS       115.0
# 4          Commercial Vehicles    NO STANDING-DAY/TIME LIMITS       115.0
#
# [5 rows x 22 columns]

# %%
final_df.to_csv('formatted_dataset.csv', encoding='utf-8', index=False)

# %%
tme='10:12A' 
pd.to_datetime(tme).strftime('%I:%M %p')
# Out:
# '10:12 AM'
